# %% [markdown]
# ![API](data:image/jpeg;base64,...)

# %%
from flask import Flask
import requests
import random

# %%
app = Flask(__name__)

# %%
@app.route("/")
def hello_world():
    return "Hello world!"

@app.route("/random-number")
def random_int():
    return str(random.randint(90000, 999999))

@app.route("/insert-into-employees")
def random_int():
    return str(random.randint(90000, 999999))

@app.route("/insert-into-employees", methods=["POST"])
def inserts_into_db():
    
    dict_ = {
    "emp_no": request.args["emp_no"],
    "birth_date": request.args["birth_date"],
    "first_name": request.args["first_name"],
    "last_name": request.args["last_name"],
    "gender": request.args["gender"],
    "hire_date": request.args["hire_date"]
    } 

    return queries.insert_into_employees(dict_)



if __name__ == "__main__":
    app.run(port=9000, debug=False)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
#       1 @app.route("/.")
# ----> 2 def hello_world():
#       3     return "Hello world!"
#       5 @app.route("/random-number")
#       6 def random_int():
#
# File ~/miniconda3/envs/ironhack/lib/python3.10/site-packages/flask/scaffold.py:449, in Scaffold.route.<locals>.decorator(f)
#     447 def decorator(f: T_route) -> T_route:
#     448     endpoint = options.pop("endpoint", None)
# --> 449     self.add_url_rule(rule, endpoint, f, **options)
#     450     return f
#
# File ~/miniconda3/envs/ironhack/lib/python3.10/site-packages/flask/scaffold.py:50, in setupmethod.<locals>.wrapper_func(self, *args, **kwargs)
#      48 def wrapper_func(self, *args: t.Any, **kwargs: t.Any) -> t.Any:
#      49     self._check_setup_finished(f_name)
# ---> 50     return f(self, *args, **kwargs)
#
# ...

# %% [markdown]
# # iteration 3

# %%
import pandas as pd
pd.read_csv("IEA-EV-dataEV stock shareCarsHistorical.csv")



requests.post("http://127.0.0.1:9000/insert-into-employees", params = dict_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 6>()
#       1 import pandas as pd
#       2 pd.read_csv("IEA-EV-dataEV stock shareCarsHistorical.csv")
# ----> 6 requests.post("http://127.0.0.1:9000/insert-into-employees", params = dict_)
#
# NameError: name 'requests' is not defined

# %%
from getpass import getpass
import sqlalchemy as alch

password = getpass()
# Out:
# ········

# %%
dbName = "sql7618809"
connectionData = f"mysql+pymysql://root:{password}@localhost/{dbName}"
engine = alch.create_engine(connectionData)

import pandas as pd
df=pd.read_csv("IEA-EV-dataEV stock shareCarsHistorical.csv")
df.to_sql("EV", if_exists="append", con=engine, index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/miniconda3/envs/ironhack/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3366, in Engine._wrap_pool_connect(self, fn, connection)
#    3365 try:
# -> 3366     return fn()
#    3367 except dialect.dbapi.Error as e:
#
# File ~/miniconda3/envs/ironhack/lib/python3.10/site-packages/sqlalchemy/pool/base.py:327, in Pool.connect(self)
#     320 """Return a DBAPI connection from the pool.
#     321
#     322 The connection is instrumented such that when its
#    (...)
#     325
#     326 """
# --> 327 return _ConnectionFairy._checkout(self)
#
# File ~/miniconda3/envs/ironhack/lib/python3.10/site-packages/sqlalchemy/pool/base.py:894, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     893 if not fairy:
# --> 894     fairy = _ConnectionRecord.checkout(pool)
#     896     fairy._pool = pool
#
# ...
